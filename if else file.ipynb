# %%
age = int(input("enter age: "))
if age>=18:
   print("you are young")
else: 
   print("you are not young")
# Out:
# enter age:  18
# you are young

# %%
# enter bill amount 50000 10% n0 dis 
bill_amount = int(input("enter bill amount"))
if bill_amount>50000:
    print("apko 10% discount mil gya")
else:
    print("sorry apko koi discount nhi mila hy")
# Out:
# enter bill amount 40000
# sorry apko koi discount nhi mila hy

# %%
bill_amount = int(input("enter bill amount"))
if bill_amount>50000:
    discount = bill_amount*.10
    print(f"your dicount is rs:{discount} on purchase of rs:{bill_amount}")
else:
    print(f"sorry you have no discount on on purchase of rs:{bill_amount}")
# Out:
# enter bill amount 60000
# your dicount is rs:6000.0 on purchase of rs:60000

# %%
{len:"hello"}
# Out:
# {<function len(obj, /)>: 'hello'}

# %% [markdown]
# # loops
#   what is loop?

# %%
for a in range(1000):
    print(a,"ubaid")
# Out:
# 0 ubaid
# 1 ubaid
# 2 ubaid
# 3 ubaid
# 4 ubaid
# 5 ubaid
# 6 ubaid
# 7 ubaid
# 8 ubaid
# 9 ubaid
# 10 ubaid
# 11 ubaid
# 12 ubaid
# 13 ubaid
# 14 ubaid
# 15 ubaid
# 16 ubaid
# 17 ubaid
# 18 ubaid
# 19 ubaid
# 20 ubaid
# 21 ubaid
# 22 ubaid
# 23 ubaid
# 24 ubaid
# 25 ubaid
# 26 ubaid
# 27 ubaid
# 28 ubaid
# 29 ubaid
# 30 ubaid
# 31 ubaid
# 32 ubaid
# 33 ubaid
# 34 ubaid
# 35 ubaid
# 36 ubaid
# 37 ubaid
# 38 ubaid
# 39 ubaid
# 40 ubaid
# 41 ubaid
# 42 ubaid
# 43 ubaid
# 44 ubaid
# 45 ubaid
# 46 ubaid
# 47 ubaid
# 48 ubaid
# 49 ubaid
# 50 ubaid
# 51 ubaid
# 52 ubaid
# 53 ubaid
# 54 ubaid
# 55 ubaid
# 56 ubaid
# 57 ubaid
# 58 ubaid
# 59 ubaid
# 60 ubaid
# 61 ubaid
# 62 ubaid
# 63 ubaid
# 64 ubaid
# 65 ubaid
# 66 ubaid
# 67 ubaid
# 68 ubaid
# 69 ubaid
# 70 ubaid
# 71 ubaid
# 72 ubaid
# 73 ubaid
# 74 ubaid
# 75 ubaid
# 76 ubaid
# 77 ubaid
# 78 ubaid
# 79 ubaid
# 80 ubaid
# 81 ubaid
# 82 ubaid
# 83 ubaid
# 84 ubaid
# 85 ubaid
# 86 ubaid
# 87 ubaid
# 88 ubaid
# 89 ubaid
# 90 ubaid
# ...
